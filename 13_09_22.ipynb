# %% [markdown]
# <a href="https://colab.research.google.com/github/ThanhQuynh0202/VoNgocThanhQuynh_20104053/blob/main/13_09_22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from openpyxl import Workbook 
wb = Workbook()
sheet = wb.active 
sheet['A1'] = 'Nguyen Van A'
sheet['B1'] = '20104001'
sheet['A2'] = 'Le Thi B'
sheet['B2'] = '20104002'
wb.save('/content/Book1.xlsx')

# %%
import openpyxl
wb = openpyxl.load_workbook('/content/Book1.xlsx')
sheet = wb.active
t1 = sheet['A1']
t2 = sheet['B1']
t3 = sheet.cell(row=2, column=1)
t4 = sheet.cell(row=2, column=2)
print(t1.value, t2.value)
print(t3.value, t4.value)
# Out:
# Nguyen Van A 20104001
# Le Thi B 20104002

# %%
import openpyxl
my_wb = openpyxl.Workbook()
my_sheet = my_wb.active
c1 = my_sheet.cell(row = 1, column = 1)
c1.value = 'Mai Tien Hai'
c2 = my_sheet.cell(row = 1, column = 2)
c2.value = 'Vo Ngoc Thanh Quynh'
c3 = my_sheet['A2']
c3.value = 'Ulsan'
c4 = my_sheet['B2']
c4.value = 'Genovoa'
my_wb.save('/content/Book1.xlsx')

# %%
import openpyxl
my_wb = openpyxl.Workbook()
my_sheet = my_wb.active
my_wb.create_sheet(index = 1, title = 'KCN')
my_wb.save('/content/Book1 (1).xlsx')

# %%
import openpyxl
my_path = '/content/Book1.xlsx'
my_wb_obj = openpyxl.load_workbook(my_path)
my_sheet_obj = my_wb_obj.active
print(my_sheet_obj.max_row)
# Out:
# 2

# %%
import openpyxl
my_path = '/content/Book1.xlsx'
my_wb_obj = openpyxl.load_workbook(my_path)
my_cell_obj = my_sheet_obj.cell(row = 1, column = 1)
print(my_cell_obj.value)
# Out:
# Mai Tien Hai

# %%
import openpyxl
path = '/content/Book1.xlsx'
My_wb_obj = openpyxl.load_workbook(path)
sheet_obj = my_wb_obj.active
print(sheet_obj.max_column)
# Out:
# 2

# %%
my_wb_obj = openpyxl.load_workbook(path)
my_sheet_obj = my_wb_obj.active
my_max_col = my_sheet_obj.max_column
for i in range(1, my_max_col + 1):
  my_cell_obj = my_sheet_obj.cell(row=1, column= i)
  print(my_cell_obj.value)
# Out:
# Mai Tien Hai
# Vo Ngoc Thanh Quynh

# %%
my_wb_obj = openpyxl.load_workbook(path)
my_sheet_obj = my_wb_obj.active
my_row = my_sheet_obj.max_row
for i in range(1, my_row + 1):
  cell_obj = my_sheet_obj.cell(row=i, column= 1)
  print(cell_obj.value)
# Out:
# Mai Tien Hai
# Ulsan

# %%
my_wb_obj = openpyxl.load_workbook(path)
my_sheet_obj = my_wb_obj.active
my_max_col = my_sheet_obj.max_column
for i in range(1, my_max_col + 1):
  cell_obj = my_sheet_obj.cell(row=2, column= i)
  print(cell_obj.value, end = ' ')
# Out:
# Ulsan Genovoa

# %%
import numpy as np
vector_row = np.array([1, 2, 3])
vector_column = np.array([[1],[2],[3]])
vector_row
vector_column
# Out:
# array([[1],
#        [2],
#        [3]])

# %%
import matplotlib.pyplot as plt
import numpy as np 
x = np.arange(6)
y = x + 1
plt.plot(x,y,'o--')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np 
x = np.arange(6)
y = x + 1
plt.plot(x,y,'o--')
plt.plot(x,-y,'o--')
plt.show()

# %%
plt.title('y=x and y=-x')
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %%
N = 16
x = np.linspace(0,15,16)
y = x
plt.plot(x,y,'o--')
plt.axis('off')
plt.show()

# %%
N = 16
x = np.linspace(0,15,16)
y = np.logspace(0.1,2,16)
plt.plot(x,y,'--o')

# %%
x = [4,5,3,1,6,7,9,2]
plt.plot(x)
plt.show()

# %%
x = [1,3,6,5,6,3,1]
plt.plot(x)
plt.show()

# %%
x = np.arange(25)
plt.plot(x)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
x = np.arange(25)
plt.plot(x,x^3 + 1)
plt.show()

# %%
x = np.arange(7)
plt.plot(x,-x**2)
plt.plot(x,-x**3)
plt.plot(x,-2*x)
plt.plot(x, -2**x)
plt.show()

# %%
x = np.arange(7)
plt.plot(x, -x**2, x, -x**3, x, -2*x, x, -2**x)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
plt.grid(True)
plt.savefig('test.png')
plt.show()

# %%
x = np.arange(7)
plt.plot(x,-x**2, '-')
plt.plot(x,-x**3, '--')
plt.plot(x,-2*x, '-.')
plt.plot(x, -2**x, ':')
plt.show()

# %%
x = np.arange(7)
plt.plot(x,-x**2, '-', color = 'red')
plt.plot(x,-x**3, '--', color = 'purple')
plt.plot(x,-2*x, '-.', color = '')
plt.plot(x, -2**x, ':')
plt.show()

# %%
x = np.arange(3)
plt.subplots_adjust(wspace = 0.3, hspace=0.3)
plt.subplot(2,2,1)
plt.show()

# %%
x = np.arange(3)
plt.subplots_adjust(wspace = 0.3, hspace=0.3)
plt.subplot(2,2,1)
plt.plot(x,-x**2, color = 'green')
plt.subplot(2,2,2)
plt.plot(x,-x**3, color = 'red')
plt.subplot(2,2,3)
plt.plot(x,-2*x, color = 'pink')
plt.subplot(2,2,4)
plt.plot(x,-2**x, color = 'blue')
plt.show()

# %%
plt.axis([0,100,0,10])
plt.scatter(60,5,1000,color = 'b', alpha = 1)
plt.scatter(80,5,s=1000,color='b', alpha=.5)
plt.scatter(10,5,s=1000,color='b', alpha =.1)
plt.show()

# %%
plt.plot([30,40],[50,60], linewidth = 5, color = 'r')
plt.text(36,58,'Text')
# Out:
# Text(36, 58, 'Text')

# %%
plt.arrow(0.2,0, 0.4-0.2,0.4-0, head_length = 4, head_width=2,color = 'g')

# %%
x = np.arange(4)
y = np.arange(4)
plt.bar(x,y)
plt.show()

# %%
y = np.random.rand(3,4)
plt.bar(x +0, y[0], color = 'b', width=0.25)
plt.bar(x+0.25, y[1], color = 'g', width = 0.25)
plt.bar(x +0.25, y[2], color = 'r', width = 0.25)
plt.show()

# %%
x = np.arange(4)
y = np.random.rand(4)
plt.bar(x,y)
plt.show()

# %%
x = np.arange(4)
y = np.random.rand(4)
plt.bar(x,y)
plt.show()

# %%
N= 1000
x = np.random.rand(N)
y = np.random.rand(N)
colors = np.random.rand(N)
size = 20
plt.scatter(x,y,s=size, c = colors, alpha =1)
plt.show()
